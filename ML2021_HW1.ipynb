# %% [markdown]
# # **Homework 1: COVID-19 Cases Prediction (Regression)**

# %% [markdown]
# # **Result**
#
# scores (pass strong baseline):
#
# ![image.png](data:image/png;base64,...)
#
# strong baseline:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Download Data**

# %%
tr_path = 'covid.train.csv'  # path to training data
tt_path = 'covid.test.csv'   # path to testing data

# !gdown --id '19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF' --output covid.train.csv
# !gdown --id '1CE240jLm2npU-tdz81-oVKEF3T2yfT1O' --output covid.test.csv
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF
# To: /content/covid.train.csv
# 100% 2.00M/2.00M [00:00<00:00, 132MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1CE240jLm2npU-tdz81-oVKEF3T2yfT1O
# To: /content/covid.test.csv
# 100% 651k/651k [00:00<00:00, 164MB/s]

# %% [markdown]
# # **Import Some Packages**

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import numpy as np
import csv
import os
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 42069
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# # **Data Analysis and Some Utilities**

# %%
train_data = pd.read_csv("/content/covid.train.csv")
train_data = train_data.drop(["id"], axis=1)
train_data.corr()
# Out:
#                             AL        AK        AZ        AR        CA  \
# AL                    1.000000 -0.025446 -0.025446 -0.025446 -0.025446
# AK                   -0.025446  1.000000 -0.025446 -0.025446 -0.025446
# AZ                   -0.025446 -0.025446  1.000000 -0.025446 -0.025446
# AR                   -0.025446 -0.025446 -0.025446  1.000000 -0.025446
# CA                   -0.025446 -0.025446 -0.025446 -0.025446  1.000000
# ...                        ...       ...       ...       ...       ...
# depressed.2          -0.035570  0.059403 -0.052381  0.218993 -0.007374
# felt_isolated.2      -0.170177  0.153638 -0.059705 -0.021997  0.058020
# worried_become_ill.2 -0.273551 -0.179413 -0.206808 -0.127898 -0.093832
# worried_finances.2   -0.047698 -0.098627 -0.157999  0.035605 -0.079045
# tested_positive.2     0.063479 -0.152682 -0.162097  0.030706 -0.208291
#
#                             CO        CT        FL        GA        ID  ...  \
# AL                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# AK                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# AZ                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# AR                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# CA                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# ...                        ...       ...       ...       ...       ...  ...
# depressed.2           0.071091 -0.159754 -0.201005 -0.129952  0.037010  ...
# felt_isolated.2       0.020721 -0.172719 -0.195154 -0.179562 -0.032974  ...
# worried_become_ill.2 -0.120136  0.038770 -0.168653 -0.203301 -0.276828  ...
# worried_finances.2   -0.123659 -0.092067 -0.065390 -0.077847 -0.188089  ...
# tested_positive.2    -0.131460 -0.227023 -0.120834 -0.051948  0.175365  ...
#
#                       restaurant.2  spent_time.2  large_event.2  \
# AL                        0.210928      0.202805       0.279239
# AK                       -0.013452      0.051009       0.029212
# AZ                        0.177914      0.108104       0.098514
# AR                        0.112250      0.146078       0.187179
# CA                        0.027648      0.016425      -0.046107
# ...                            ...           ...            ...
# depressed.2              -0.067040      0.118125       0.066021
# felt_isolated.2          -0.641984     -0.507902      -0.554675
# worried_become_ill.2     -0.831868     -0.870630      -0.875487
# worried_finances.2       -0.435929     -0.524228      -0.380926
# tested_positive.2        -0.160181     -0.258956      -0.063709
#
#                       public_transit.2  anxious.2  depressed.2  \
# AL                           -0.073966  -0.153556    -0.035570
# AK                            0.194813   0.017483     0.059403
# AZ                            0.087006  -0.136689    -0.052381
# AR                           -0.117037   0.077963     0.218993
# CA                            0.104119  -0.018843    -0.007374
# ...                                ...        ...          ...
# depressed.2                  -0.164079   0.594797     1.000000
# felt_isolated.2               0.009571   0.525171     0.610310
# worried_become_ill.2         -0.047068   0.251509    -0.051246
# worried_finances.2           -0.142098   0.184126     0.026621
# tested_positive.2            -0.450436   0.152903     0.029578
#
#                       felt_isolated.2  worried_become_ill.2  \
# AL                          -0.170177             -0.273551
# AK                           0.153638             -0.179413
# AZ                          -0.059705             -0.206808
# AR                          -0.021997             -0.127898
# CA                           0.058020             -0.093832
# ...                               ...                   ...
# depressed.2                  0.610310             -0.051246
# felt_isolated.2              1.000000              0.407931
# worried_become_ill.2         0.407931              1.000000
# worried_finances.2           0.132465              0.495890
# tested_positive.2            0.081174              0.267610
#
#                       worried_finances.2  tested_positive.2
# AL                             -0.047698           0.063479
# AK                             -0.098627          -0.152682
# AZ                             -0.157999          -0.162097
# AR                              0.035605           0.030706
# CA                             -0.079045          -0.208291
# ...                                  ...                ...
# depressed.2                     0.026621           0.029578
# felt_isolated.2                 0.132465           0.081174
# worried_become_ill.2            0.495890           0.267610
# worried_finances.2              1.000000           0.485843
# tested_positive.2               0.485843           1.000000
#
# [94 rows x 94 columns]

# %%
feats = []
for idx, data in enumerate(train_data.corr()["tested_positive.2"].abs()):
  if data > 0.48 and idx != 93:
    feats.append(idx)

print(feats)
# Out:
# 40
# 41
# 42
# 43
# 57
# 58
# 59
# 60
# 61
# 74
# 75
# 76
# 77
# 78
# 79
# 92

# %%
with open("/content/covid.train.csv", "r") as fp:
    train_data = list(csv.reader(fp))
    train_data = np.array(train_data[1:])[:, 1:-1].astype(float)

mean = torch.FloatTensor(train_data[:, feats]).mean(dim=0, keepdim=True)
std = torch.FloatTensor(train_data[:, feats]).std(dim=0, keepdim=True)

# %%
with open("/content/covid.train.csv") as fp:
  train_data = list(csv.reader(fp))
  train_data = np.array(train_data[1:])[:, 1:-1].astype(float)

# %%
mean = torch.FloatTensor(train_data[:, feats]).mean(dim=0, keepdim=True)
std = torch.FloatTensor(train_data[:, feats]).std(dim=0, keepdim=True)

# %%
def get_device():
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()


def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# # **Dataset and DataLoader**

# %%
class COVID19Dataset(Dataset):
    def __init__(self, path, mode='train', target_only=False):
        self.mode = mode

        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)

        if mode == 'test':
          data = data[:, feats]
          self.data = torch.FloatTensor(data)

        else:
          target = data[:, -1]
          data = data[:, feats]

          if mode == 'train':
            indices = [i for i in range(len(data)) if i % 10 != 0]
          elif mode == 'dev':
            indices = [i for i in range(len(data)) if i % 10 == 0]

          self.data = torch.FloatTensor(data[indices])
          self.target = torch.FloatTensor(target[indices])


        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

        self.data = (self.data - mean) / std

    def __getitem__(self, index):

        if self.mode in ['train', 'dev']:

            return self.data[index], self.target[index]
        else:

            return self.data[index]

    def __len__(self):

        return len(self.data)

# %%
def prep_dataloader(path, mode, batch_size, n_jobs=0, target_only=False):
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)
    return dataloader

# %% [markdown]
# # **Deep Neural Network**

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
      loss = self.criterion(pred, target)
      l2 = 0
      for i in self.parameters():
        l2 += torch.sum(pow(i, 2))

      return loss + 0.002 * l2, loss

# %% [markdown]
# # **Train/Dev/Test**

# %%
def train(tr_set, dv_set, model, config, device):

    n_epochs = config['n_epochs']

    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()
        for x, y in tr_set:
            optimizer.zero_grad()
            x, y = x.to(device), y.to(device)
            pred = model(x)
            l2_loss, mse_loss = model.cal_loss(pred, y)
            l2_loss.backward()
            optimizer.step()
            loss_record['train'].append(mse_loss.detach().cpu().item())

        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %%
def dev(dv_set, model, device):
    model.eval()
    total_loss = 0
    for x, y in dv_set:
        x, y = x.to(device), y.to(device)
        with torch.no_grad():
            pred = model(x)
            _, mse_loss = model.cal_loss(pred, y)
        total_loss += mse_loss.detach().cpu().item() * len(x)
    total_loss = total_loss / len(dv_set.dataset)
    return total_loss

# %%
def test(tt_set, model, device):
    model.eval()
    preds = []
    for x in tt_set:
        x = x.to(device)
        with torch.no_grad():
            pred = model(x)
            preds.append(pred.detach().cpu())
    preds = torch.cat(preds, dim=0).numpy()
    return preds

# %% [markdown]
# # **Setup Hyper-parameters**

# %%
device = get_device()
os.makedirs('models', exist_ok=True)
target_only = False

config = {
    'n_epochs': 3000,
    'batch_size': 128,
    'optimizer': 'SGD',
    'optim_hparas': {
        'lr': 0.0001,
        'momentum': 0.9
    },
    'early_stop': 200,
    'save_path': 'models/model.pth'
}

# %% [markdown]
# # **Load data and model**

# %%
tr_set = prep_dataloader(tr_path, 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataloader(tr_path, 'dev', config['batch_size'], target_only=target_only)
tt_set = prep_dataloader(tt_path, 'test', config['batch_size'], target_only=target_only)
# Out:
# Finished reading the train set of COVID19 Dataset (2430 samples found, each dim = 16)
# Finished reading the dev set of COVID19 Dataset (270 samples found, each dim = 16)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 16)

# %%
model = NeuralNet(tr_set.dataset.dim).to(device)

# %% [markdown]
# # **Start Training**

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 278.9100)
# Saving model (epoch =    2, loss = 150.9659)
# Saving model (epoch =    3, loss = 84.5797)
# Saving model (epoch =    4, loss = 66.4972)
# Saving model (epoch =    5, loss = 55.1837)
# Saving model (epoch =    6, loss = 46.4203)
# Saving model (epoch =    7, loss = 38.2055)
# Saving model (epoch =    8, loss = 30.0125)
# Saving model (epoch =    9, loss = 21.9222)
# Saving model (epoch =   10, loss = 14.6550)
# Saving model (epoch =   11, loss = 9.2592)
# Saving model (epoch =   12, loss = 6.0920)
# Saving model (epoch =   13, loss = 4.3830)
# Saving model (epoch =   14, loss = 3.4788)
# Saving model (epoch =   15, loss = 2.9525)
# Saving model (epoch =   16, loss = 2.5050)
# Saving model (epoch =   17, loss = 2.1954)
# Saving model (epoch =   18, loss = 1.9563)
# Saving model (epoch =   19, loss = 1.7855)
# Saving model (epoch =   20, loss = 1.6720)
# Saving model (epoch =   21, loss = 1.5764)
# Saving model (epoch =   22, loss = 1.5016)
# Saving model (epoch =   23, loss = 1.4401)
# Saving model (epoch =   24, loss = 1.3899)
# Saving model (epoch =   25, loss = 1.3504)
# Saving model (epoch =   26, loss = 1.3147)
# Saving model (epoch =   27, loss = 1.2812)
# Saving model (epoch =   28, loss = 1.2548)
# Saving model (epoch =   29, loss = 1.2350)
# Saving model (epoch =   30, loss = 1.2116)
# Saving model (epoch =   31, loss = 1.1943)
# Saving model (epoch =   32, loss = 1.1807)
# Saving model (epoch =   33, loss = 1.1673)
# Saving model (epoch =   34, loss = 1.1532)
# Saving model (epoch =   35, loss = 1.1467)
# Saving model (epoch =   36, loss = 1.1400)
# Saving model (epoch =   37, loss = 1.1283)
# Saving model (epoch =   38, loss = 1.1262)
# Saving model (epoch =   39, loss = 1.1151)
# Saving model (epoch =   40, loss = 1.1078)
# Saving model (epoch =   41, loss = 1.1058)
# Saving model (epoch =   42, loss = 1.0993)
# Saving model (epoch =   43, loss = 1.0967)
# Saving model (epoch =   44, loss = 1.0914)
# Saving model (epoch =   45, loss = 1.0872)
# Saving model (epoch =   46, loss = 1.0812)
# Saving model (epoch =   47, loss = 1.0792)
# Saving model (epoch =   49, loss = 1.0732)
# Saving model (epoch =   50, loss = 1.0681)
# Saving model (epoch =   51, loss = 1.0634)
# Saving model (epoch =   52, loss = 1.0606)
# Saving model (epoch =   53, loss = 1.0605)
# Saving model (epoch =   54, loss = 1.0571)
# Saving model (epoch =   55, loss = 1.0549)
# Saving model (epoch =   56, loss = 1.0485)
# Saving model (epoch =   59, loss = 1.0428)
# Saving model (epoch =   60, loss = 1.0424)
# Saving model (epoch =   61, loss = 1.0355)
# Saving model (epoch =   62, loss = 1.0351)
# Saving model (epoch =   64, loss = 1.0335)
# Saving model (epoch =   65, loss = 1.0279)
# Saving model (epoch =   66, loss = 1.0272)
# Saving model (epoch =   67, loss = 1.0254)
# Saving model (epoch =   68, loss = 1.0246)
# Saving model (epoch =   69, loss = 1.0206)
# Saving model (epoch =   70, loss = 1.0201)
# Saving model (epoch =   71, loss = 1.0171)
# Saving model (epoch =   73, loss = 1.0117)
# Saving model (epoch =   74, loss = 1.0114)
# Saving model (epoch =   75, loss = 1.0099)
# Saving model (epoch =   77, loss = 1.0054)
# Saving model (epoch =   79, loss = 1.0013)
# Saving model (epoch =   80, loss = 1.0011)
# Saving model (epoch =   81, loss = 1.0006)
# Saving model (epoch =   82, loss = 0.9974)
# Saving model (epoch =   84, loss = 0.9948)
# Saving model (epoch =   87, loss = 0.9928)
# Saving model (epoch =   88, loss = 0.9891)
# Saving model (epoch =   89, loss = 0.9889)
# Saving model (epoch =   91, loss = 0.9850)
# Saving model (epoch =   92, loss = 0.9838)
# Saving model (epoch =   94, loss = 0.9824)
# Saving model (epoch =   95, loss = 0.9821)
# Saving model (epoch =   96, loss = 0.9798)
# Saving model (epoch =   99, loss = 0.9747)
# Saving model (epoch =  102, loss = 0.9705)
# Saving model (epoch =  107, loss = 0.9671)
# Saving model (epoch =  109, loss = 0.9648)
# Saving model (epoch =  110, loss = 0.9638)
# Saving model (epoch =  111, loss = 0.9634)
# Saving model (epoch =  113, loss = 0.9608)
# Saving model (epoch =  115, loss = 0.9592)
# Saving model (epoch =  116, loss = 0.9561)
# Saving model (epoch =  118, loss = 0.9558)
# Saving model (epoch =  119, loss = 0.9546)
# Saving model (epoch =  122, loss = 0.9533)
# Saving model (epoch =  124, loss = 0.9493)
# Saving model (epoch =  126, loss = 0.9478)
# Saving model (epoch =  128, loss = 0.9476)
# Saving model (epoch =  130, loss = 0.9443)
# Saving model (epoch =  132, loss = 0.9432)
# Saving model (epoch =  133, loss = 0.9417)
# Saving model (epoch =  135, loss = 0.9416)
# Saving model (epoch =  137, loss = 0.9382)
# Saving model (epoch =  139, loss = 0.9368)
# Saving model (epoch =  141, loss = 0.9362)
# Saving model (epoch =  143, loss = 0.9353)
# Saving model (epoch =  144, loss = 0.9326)
# Saving model (epoch =  147, loss = 0.9311)
# Saving model (epoch =  149, loss = 0.9286)
# Saving model (epoch =  152, loss = 0.9285)
# Saving model (epoch =  153, loss = 0.9274)
# Saving model (epoch =  154, loss = 0.9260)
# Saving model (epoch =  156, loss = 0.9249)
# Saving model (epoch =  158, loss = 0.9224)
# Saving model (epoch =  160, loss = 0.9217)
# Saving model (epoch =  162, loss = 0.9195)
# Saving model (epoch =  166, loss = 0.9189)
# Saving model (epoch =  167, loss = 0.9182)
# Saving model (epoch =  168, loss = 0.9149)
# Saving model (epoch =  170, loss = 0.9149)
# Saving model (epoch =  171, loss = 0.9137)
# Saving model (epoch =  174, loss = 0.9113)
# Saving model (epoch =  176, loss = 0.9104)
# Saving model (epoch =  179, loss = 0.9098)
# Saving model (epoch =  180, loss = 0.9077)
# Saving model (epoch =  184, loss = 0.9062)
# Saving model (epoch =  185, loss = 0.9055)
# Saving model (epoch =  188, loss = 0.9046)
# Saving model (epoch =  190, loss = 0.9020)
# Saving model (epoch =  194, loss = 0.9006)
# Saving model (epoch =  197, loss = 0.8984)
# Saving model (epoch =  199, loss = 0.8984)
# Saving model (epoch =  200, loss = 0.8983)
# Saving model (epoch =  203, loss = 0.8969)
# Saving model (epoch =  207, loss = 0.8960)
# Saving model (epoch =  209, loss = 0.8926)
# Saving model (epoch =  210, loss = 0.8923)
# Saving model (epoch =  211, loss = 0.8915)
# Saving model (epoch =  219, loss = 0.8905)
# Saving model (epoch =  222, loss = 0.8879)
# Saving model (epoch =  223, loss = 0.8859)
# Saving model (epoch =  228, loss = 0.8843)
# Saving model (epoch =  232, loss = 0.8827)
# Saving model (epoch =  235, loss = 0.8818)
# Saving model (epoch =  240, loss = 0.8818)
# Saving model (epoch =  242, loss = 0.8814)
# Saving model (epoch =  243, loss = 0.8804)
# Saving model (epoch =  245, loss = 0.8776)
# Saving model (epoch =  250, loss = 0.8770)
# Saving model (epoch =  255, loss = 0.8768)
# Saving model (epoch =  257, loss = 0.8747)
# Saving model (epoch =  260, loss = 0.8733)
# Saving model (epoch =  264, loss = 0.8723)
# Saving model (epoch =  271, loss = 0.8722)
# Saving model (epoch =  272, loss = 0.8720)
# Saving model (epoch =  273, loss = 0.8706)
# Saving model (epoch =  279, loss = 0.8694)
# Saving model (epoch =  280, loss = 0.8686)
# Saving model (epoch =  284, loss = 0.8667)
# Saving model (epoch =  292, loss = 0.8650)
# Saving model (epoch =  297, loss = 0.8642)
# Saving model (epoch =  300, loss = 0.8631)
# Saving model (epoch =  304, loss = 0.8615)
# Saving model (epoch =  312, loss = 0.8610)
# Saving model (epoch =  315, loss = 0.8596)
# Saving model (epoch =  322, loss = 0.8585)
# Saving model (epoch =  326, loss = 0.8583)
# Saving model (epoch =  327, loss = 0.8579)
# Saving model (epoch =  331, loss = 0.8570)
# Saving model (epoch =  337, loss = 0.8559)
# Saving model (epoch =  340, loss = 0.8556)
# Saving model (epoch =  343, loss = 0.8548)
# Saving model (epoch =  350, loss = 0.8538)
# Saving model (epoch =  354, loss = 0.8521)
# Saving model (epoch =  359, loss = 0.8520)
# Saving model (epoch =  364, loss = 0.8518)
# Saving model (epoch =  367, loss = 0.8507)
# Saving model (epoch =  372, loss = 0.8501)
# Saving model (epoch =  378, loss = 0.8500)
# Saving model (epoch =  381, loss = 0.8493)
# Saving model (epoch =  385, loss = 0.8470)
# Saving model (epoch =  411, loss = 0.8452)
# Saving model (epoch =  420, loss = 0.8451)
# Saving model (epoch =  424, loss = 0.8432)
# Saving model (epoch =  432, loss = 0.8427)
# Saving model (epoch =  452, loss = 0.8410)
# Saving model (epoch =  481, loss = 0.8393)
# Saving model (epoch =  486, loss = 0.8382)
# Saving model (epoch =  513, loss = 0.8381)
# Saving model (epoch =  517, loss = 0.8371)
# Saving model (epoch =  524, loss = 0.8366)
# Saving model (epoch =  536, loss = 0.8354)
# Saving model (epoch =  563, loss = 0.8353)
# Saving model (epoch =  579, loss = 0.8351)
# Saving model (epoch =  581, loss = 0.8350)
# Saving model (epoch =  596, loss = 0.8337)
# Saving model (epoch =  605, loss = 0.8335)
# Saving model (epoch =  613, loss = 0.8329)
# Saving model (epoch =  622, loss = 0.8312)
# Saving model (epoch =  644, loss = 0.8312)
# Saving model (epoch =  660, loss = 0.8309)
# Saving model (epoch =  683, loss = 0.8300)
# Saving model (epoch =  719, loss = 0.8300)
# Saving model (epoch =  729, loss = 0.8288)
# Saving model (epoch =  787, loss = 0.8285)
# Saving model (epoch =  799, loss = 0.8283)
# Saving model (epoch =  813, loss = 0.8280)
# Saving model (epoch =  846, loss = 0.8278)
# Saving model (epoch =  884, loss = 0.8274)
# Saving model (epoch =  976, loss = 0.8267)
# Saving model (epoch = 1159, loss = 0.8267)
# Saving model (epoch = 1194, loss = 0.8266)
# Saving model (epoch = 1203, loss = 0.8265)
# Saving model (epoch = 1204, loss = 0.8262)
# Saving model (epoch = 1245, loss = 0.8261)
# Saving model (epoch = 1251, loss = 0.8258)
# Saving model (epoch = 1372, loss = 0.8258)
# Saving model (epoch = 1494, loss = 0.8257)
# Saving model (epoch = 1620, loss = 0.8256)
# Saving model (epoch = 1720, loss = 0.8256)
# Saving model (epoch = 1729, loss = 0.8253)
# Saving model (epoch = 1769, loss = 0.8248)
# Saving model (epoch = 1808, loss = 0.8247)
# Saving model (epoch = 1834, loss = 0.8247)
# Saving model (epoch = 1906, loss = 0.8245)
# Finished training after 2107 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)

# %% [markdown]
# # **Testing**

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)
save_pred(preds, 'pred.csv')
# Out:
# Saving results to pred.csv
